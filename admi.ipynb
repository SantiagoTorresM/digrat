# %% [markdown]
# **Gobierno de datos**
# ## DATA
# La administración de las bases de datos se va a estructurar bajo el enfoque CRISP-DM.
#
# En Sunedu, de acuerdo al ROF, la Dirección de Documentación, Información Universitaria y Grados y Títulos tiene a cargo la administración de información relacionada al sistema de educación superior universitario. En esa línea, se ha identificado la existencia de las siguientes bases de datos que contiene información vinculada:
#
# |N°|Bases de datos|Descripción|Administrador|Periodos disponibles|Gobierno|Variables|Observaciones en promedio
# | :- | :- | :- | :- | :- | :- | :- | :-
# |1|SIBE|Información de oferta y demanda en ESU por carreras|DIGRAT|2014-2017|DIGRAT-UDIU|x|Diversas
# |2|ANR|Información de oferta y demanda en ESU general|DIGRAT|2000-2013|DIGRAT-UDIU|x|Diversas
# |3|DILIC|Información de oferta en ESU según status de licenciamiento, docentes, infraestructura, mallas|DILIC|2016-2020|DILIC|x|Diversas
# |4|ENAHO|Información socio económica y laboral de profesionales|INEI|2004-2018|INEI|x|Aprox 100 mil obs.
# |5|AIRSHP|Información de la planilla docente en universidades públicas|MEF|2019|MEF||
# |6|C9|Información de la plana docente en universidades públicas y privadas|DILIC|2016-2020|DILIC|x|Diversas
# |7|CENAUN|Censo Universitario, pregrado, posgrado, docentes, facultad y universidad|INEI|2010|INEI|x|Diversas
# |8|CARNÉS|Información de matrícula sujeta a emisión de carnés universitarios|DIGRAT|2017-2019|DIGRAT|x|Diversas
# |9|GYT|Información de registro de grados y títulos de profesionales en ESU registrados en Sunedu|DIGRAT|2014-2019|DIGRAT|x|Diversas
# ||||||||
# ||||||||
# ||||||||
# ||||||||
# ||||||||

# %% [markdown]
# **Lectura de databases SIBE**

# %%
import itables.interactive
import world_bank_data as wb
import pandas as pd

df = wb.get_countries()
df.head(35)
# Out:
#     iso2Code                                               name  \
# id
# ABW       AW                                              Aruba
# AFG       AF                                        Afghanistan
# AFR       A9                                             Africa
# AGO       AO                                             Angola
# ALB       AL                                            Albania
# AND       AD                                            Andorra
# ANR       L5                                      Andean Region
# ARB       1A                                         Arab World
# ARE       AE                               United Arab Emirates
# ARG       AR                                          Argentina
# ARM       AM                                            Armenia
# ASM       AS                                     American Samoa
# ATG       AG                                Antigua and Barbuda
# AUS       AU                                          Australia
# ...

# %%
e2014 = pd.read_csv('C:/Users/sant_/OneDrive - Universidad Adolfo Ibanez/sunedu2020/src/e2014.csv', encoding = 'UTF-8', sep = ';')
e2015 = pd.read_csv('C:/Users/sant_/OneDrive - Universidad Adolfo Ibanez/sunedu2020/src/e2015.csv', encoding = 'UTF-8', sep = ';')
print('Postulantes Año 2014')
show(e2014, maxBytes=0)
print('Postulantes Año 2015')
show(e2015, maxBytes=0)
# Out:
# Postulantes Año 2014
# <div><table id="4a7f9fcb-0680-49ad-8e27-64827c9f0774" class="display"><thead>
#     <tr style="text-align: right;">
#
#       <th>Dim Sexo.Desc Sexo</th>
#       <th>FAMILIA DE CARRERAS</th>
#       <th>NIVEL PROGRAMA</th>
#       <th>PROGRAMAS DE ESTUDIO</th>
#       <th>TIPO DE GESTIÓN</th>
#       <th>UNIVERSIDAD</th>
#       <th>Cant Estudiantes</th>
#     </tr>
#   </thead></table>
# <script type="text/javascript">
# require(["datatables"], function (datatables) {
#     $(document).ready(function () {
# ...

# %%
from itables import show

x = wb.get_series("SP.POP.TOTL", mrv=1, simplify_index=True)
show(x)
# Out:
# <div><table id="15f8cf81-6637-46c8-9d57-56e1a32c31ca" class="display"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>SP.POP.TOTL</th>
#     </tr>
#     <tr>
#       <th>Country</th>
#       <th></th>
#     </tr>
#   </thead></table>
# <script type="text/javascript">
# require(["datatables"], function (datatables) {
#     $(document).ready(function () {
# ...

# %%
import itables.options as opt

opt.lengthMenu = [2, 5, 10, 20, 50, 100, 200, 500]
df
# Out:
#     iso2Code                                               name  \
# id
# ABW       AW                                              Aruba
# AFG       AF                                        Afghanistan
# AFR       A9                                             Africa
# AGO       AO                                             Angola
# ALB       AL                                            Albania
# AND       AD                                            Andorra
# ANR       L5                                      Andean Region
# ARB       1A                                         Arab World
# ARE       AE                               United Arab Emirates
# ARG       AR                                          Argentina
# ARM       AM                                            Armenia
# ASM       AS                                     American Samoa
# ATG       AG                                Antigua and Barbuda
# AUS       AU                                          Australia
# ...

# %%
show(df.head(), paging=False)
# Out:
# <div><table id="982c8297-736a-4f05-a483-a577d2b83a58" class="display"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>iso2Code</th>
#       <th>name</th>
#       <th>region</th>
#       <th>adminregion</th>
#       <th>incomeLevel</th>
#       <th>lendingType</th>
#       <th>capitalCity</th>
#       <th>longitude</th>
#       <th>latitude</th>
#     </tr>
#     <tr>
#       <th>id</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead></table>
# <script type="text/javascript">
# require(["datatables"], function (datatables) {
#     $(document).ready(function () {
# ...

# %%
show(df, scrollY="200px", scrollCollapse=True, paging=False)
# Out:
# <div><table id="d409a268-d409-4794-a803-2c3b487f1b65" class="display"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>iso2Code</th>
#       <th>name</th>
#       <th>region</th>
#       <th>adminregion</th>
#       <th>incomeLevel</th>
#       <th>lendingType</th>
#       <th>capitalCity</th>
#       <th>longitude</th>
#       <th>latitude</th>
#     </tr>
#     <tr>
#       <th>id</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead></table>
# <script type="text/javascript">
# require(["datatables"], function (datatables) {
#     $(document).ready(function () {
# ...

# %%
opt.classes = ["display", "nowrap"]
df
# Out:
#     iso2Code                                               name  \
# id
# ABW       AW                                              Aruba
# AFG       AF                                        Afghanistan
# AFR       A9                                             Africa
# AGO       AO                                             Angola
# ALB       AL                                            Albania
# AND       AD                                            Andorra
# ANR       L5                                      Andean Region
# ARB       1A                                         Arab World
# ARE       AE                               United Arab Emirates
# ARG       AR                                          Argentina
# ARM       AM                                            Armenia
# ASM       AS                                     American Samoa
# ATG       AG                                Antigua and Barbuda
# AUS       AU                                          Australia
# ...

# %%
opt.classes = ["display", "cell-border"]
df
# Out:
#     iso2Code                                               name  \
# id
# ABW       AW                                              Aruba
# AFG       AF                                        Afghanistan
# AFR       A9                                             Africa
# AGO       AO                                             Angola
# ALB       AL                                            Albania
# AND       AD                                            Andorra
# ANR       L5                                      Andean Region
# ARB       1A                                         Arab World
# ARE       AE                               United Arab Emirates
# ARG       AR                                          Argentina
# ARM       AM                                            Armenia
# ASM       AS                                     American Samoa
# ATG       AG                                Antigua and Barbuda
# AUS       AU                                          Australia
# ...
